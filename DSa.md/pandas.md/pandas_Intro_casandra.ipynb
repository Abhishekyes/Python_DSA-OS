# %% [markdown]
# # # Cassandra

# %%
#sql Limitation
"""
1.hold structure data
2.schema store in 
3.future cant add another col
"""
# Out:
# '\n1.hold structure data\n2.schema store in \n3.future cant add another col\n'

# %%
#fb -> cassandra(use -> ms,mc,fb etc)

# %%
"""casandra databases (horizonatal scalable)use lots of 
1.scalability (req 100gb than next day need 1000gb so : 100gb+100gb+100gb)
2.High availablity [mumbai,verginia]
30decentalized
4.saclable
"""

# %%
# DARASRAX ->free

# %%
# !pip install cassandra-driver
# Out:
# ...
#   Using cached cassandra_driver-3.25.0-cp39-cp39-win_amd64.whl
# ...
#   Using cached geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# ...

# %%
import pandas as pd

# %%
data = pd.read_excel("AWS.xlsx")
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14168\2526058094.py in <module>
# ----> 1 data = pd.read_excel("AWS.xlsx",sheet_name="Allocations")
#       2 data.head(5)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     463
#     464     try:
# ...

# %%
## operation

# %%
pd.read_excel("AWS.xlsx",skiprows=[2,5,8])
# Out:
#    AWS TRAINING - FINAL YEAR 2023 BATCH     Unnamed: 1       Unnamed: 2  \
# 0                                   SN         ROLL NO             NAME
# 1                                     2  1902310100006  Aditya Kaushik
# 2                                     3  1907830100007   Ajay Kumar ***
# 3                                     5  1902310100009            Akhil
# 4                                     6  1907830100009    Aman Singh***
# ..                                  ...            ...              ...
# 94                                   97  2002310409008           Ujjwal
# 95                                   98  1907830400028    Vaibhav Sagar
# 96                                   99  1902310400032   Vishal Sharma
# 97                                  100  1902310400033       Viveksheel
# 98                                  101  1907830400031       Yash kumar
#
#       Unnamed: 3 Unnamed: 4           Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
data.dtypes
# Out:
# AWS TRAINING - FINAL YEAR 2023 BATCH    object
# Unnamed: 1                              object
# Unnamed: 2                              object
# Unnamed: 3                              object
# Unnamed: 4                              object
# Unnamed: 5                              object
# Unnamed: 6                              object
# Unnamed: 7                              object
# Unnamed: 8                              object
# Unnamed: 9                              object
# dtype: object

# %%
df = data.copy()

# %%
df.tail(5)
# Out:
#     AWS TRAINING - FINAL YEAR 2023 BATCH     Unnamed: 1      Unnamed: 2  \
# 97                                    97  2002310409008          Ujjwal
# 98                                    98  1907830400028   Vaibhav Sagar
# 99                                    99  1902310400032  Vishal Sharma
# 100                                  100  1902310400033      Viveksheel
# 101                                  101  1907830400031      Yash kumar
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 97     8869093942         ME    PRESENT    PRESENT    PRESENT          8
# 98     7300682724         ME    PRESENT    PRESENT    PRESENT          8
# 99   90135 90704          ME    PRESENT        NaN        NaN          6
# 100    8448620136         ME    PRESENT        NaN        NaN         10
# 101    8800842098         ME    PRESENT    PRESENT    PRESENT          9
#
#     Unnamed: 9
# 97   66.666667
# 98   66.666667
# 99          50
# 100  83.333333
# ...

# %%
df.columns
# Out:
# Index(['AWS TRAINING - FINAL YEAR 2023 BATCH', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df.dtypes
# Out:
# AWS TRAINING - FINAL YEAR 2023 BATCH    object
# Unnamed: 1                              object
# Unnamed: 2                              object
# Unnamed: 3                              object
# Unnamed: 4                              object
# Unnamed: 5                              object
# Unnamed: 6                              object
# Unnamed: 7                              object
# Unnamed: 8                              object
# Unnamed: 9                              object
# dtype: object

# %%
a =df[['Unnamed: 5','Unnamed: 6','Unnamed: 2']]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a
# Out:
#               Unnamed: 5  Unnamed: 6       Unnamed: 2
# 0    2022-10-09 00:00:00  17/09/2022             NAME
# 1                PRESENT     PRESENT         Ankit***
# 2                    NaN     PRESENT  Aditya Kaushik
# 3                PRESENT         NaN   Ajay Kumar ***
# 4                    NaN     PRESENT     Ajay pal ***
# ..                   ...         ...              ...
# 97               PRESENT     PRESENT           Ujjwal
# 98               PRESENT     PRESENT    Vaibhav Sagar
# 99               PRESENT         NaN   Vishal Sharma
# 100              PRESENT         NaN       Viveksheel
# 101              PRESENT     PRESENT       Yash kumar
#
# [102 rows x 3 columns]

# %% [markdown]
# # Panda's_2

# %%
import pandas as pd

# %%
## import html file 
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 66B4-6E35
#
#  Directory of C:\Users\yoges\pythonFolder\pandas_working_numpy
#
# 20-Jan-23  03:38 PM    <DIR>          .
# 20-Jan-23  03:38 PM    <DIR>          ..
# 17-Jan-23  07:25 PM    <DIR>          .ipynb_checkpoints
# 16-Jan-23  07:19 PM        17,505,704 AWS.xlsx
# 18-Jan-23  09:31 PM            35,026 json_re.csv
# 17-Jan-23  05:20 PM            34,544 json_res.csv
# 20-Jan-23  04:03 PM            78,961 NBA.csv
# 19-Jan-23  03:23 PM            80,712 Pandas_2.ipynb
# 20-Jan-23  03:38 PM           334,444 pandas_Intro_casandra.ipynb
# 16-Jan-23  07:20 PM        84,407,139 ts_transport_vehicle_online_sales_25_10_2018to31_12_2018.csv
# 16-Jan-23  07:32 PM                 0 untitled.txt
#                8 File(s)    102,476,530 bytes
#                3 Dir(s)  60,549,525,504 bytes free

# %%
d = """
{"name" : "abhishek",
 "email" : "vvabhi2776@gmail.com",
 "study" :"bteh",
 "year" : ["4th","7thsem","now"],
 "sub" : ["ai","dl","ml"]
}
"""

# %%
#send data 1 to other plat(check "json viewer")
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'abhishek',
#  'email': 'vvabhi2776@gmail.com',
#  'study': 'bteh',
#  'year': ['4th', '7thsem', 'now'],
#  'sub': ['ai', 'dl', 'ml']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#        name                 email study    year sub
# 0  abhishek  vvabhi2776@gmail.com  bteh     4th  ai
# 1  abhishek  vvabhi2776@gmail.com  bteh  7thsem  dl
# 2  abhishek  vvabhi2776@gmail.com  bteh     now  ml

# %%
result["sub"]
# Out:
# ['ai', 'dl', 'ml']

# %%
pd.DataFrame(result["sub"])
# Out:
#     0
# 0  ai
# 1  dl
# 2  ml

# %%
# resolving val issues by remove that key 
d1 = """
{"name" : "abhishek",
 "email" : "vvabhi2776@gmail.com",
 "study" :"bteh",
 "year" : ["4th","7thsem"],
 "sub" : ["ai","dl","ml"]
}
"""

# %%
r1 = json.loads(d1)

# %%
r1
# Out:
# {'name': 'abhishek',
#  'email': 'vvabhi2776@gmail.com',
#  'study': 'bteh',
#  'year': ['4th', '7thsem'],
#  'sub': ['ai', 'dl', 'ml']}

# %%
k = r1["year"]

# %%
k
# Out:
# ['4th', '7thsem']

# %%
del r1["year"]

# %%
r1
# Out:
# {'name': 'abhishek',
#  'email': 'vvabhi2776@gmail.com',
#  'study': 'bteh',
#  'sub': ['ai', 'dl', 'ml']}

# %%
pd.DataFrame(r1)
# Out:
#        name                 email study sub
# 0  abhishek  vvabhi2776@gmail.com  bteh  ai
# 1  abhishek  vvabhi2776@gmail.com  bteh  dl
# 2  abhishek  vvabhi2776@gmail.com  bteh  ml

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
import pandas as pd
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
x = requests.get(url)

# %%
x
# Out:
# <Response [200]>

# %%
data1 = x.json()
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50888',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50888/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50888/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50888/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50888',
#   'id': 1550501173,
#   'node_id': 'PR_kwDOAA0YD85IMfRc',
#   'number': 50888,
#   'title': 'Gitpod docs: added missing line break',
#   'user': {'login': 'noatamir',
#    'id': 6564007,
#    'node_id': 'MDQ6VXNlcjY1NjQwMDc=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6564007?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/noatamir',
#    'html_url': 'https://github.com/noatamir',
#    'followers_url': 'https://api.github.com/users/noatamir/followers',
# ...

# %%
len(data1)
# Out:
# 30

# %%
## extract the dict in dict in dict in id
data1[0]['user']['id']
# Out:
# 6564007

# %%
## see all userid of 2nd table same dataset
for i in range(len(data1)):
    print(data1[1]['user']['id'])
# Out:
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632
# 33491632

# %%
df2 =pd.DataFrame(data1,columns = ['id','url','repository_url','labels_url','user'])
df2
# Out:
#             id                                                url  \
# 0   1550501173  https://api.github.com/repos/pandas-dev/pandas...
# 1   1550496896  https://api.github.com/repos/pandas-dev/pandas...
# 2   1550298700  https://api.github.com/repos/pandas-dev/pandas...
# 3   1550298038  https://api.github.com/repos/pandas-dev/pandas...
# 4   1550201142  https://api.github.com/repos/pandas-dev/pandas...
# 5   1550197033  https://api.github.com/repos/pandas-dev/pandas...
# 6   1550192983  https://api.github.com/repos/pandas-dev/pandas...
# 7   1550190973  https://api.github.com/repos/pandas-dev/pandas...
# 8   1550120694  https://api.github.com/repos/pandas-dev/pandas...
# 9   1550060102  https://api.github.com/repos/pandas-dev/pandas...
# 10  1550028797  https://api.github.com/repos/pandas-dev/pandas...
# 11  1550004817  https://api.github.com/repos/pandas-dev/pandas...
# 12  1550000207  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df2.to_csv('json_re.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 66B4-6E35
#
#  Directory of C:\Users\yoges\pythonFolder\pandas_working_numpy
#
# 20-Jan-23  03:38 PM    <DIR>          .
# 20-Jan-23  03:38 PM    <DIR>          ..
# 17-Jan-23  07:25 PM    <DIR>          .ipynb_checkpoints
# 16-Jan-23  07:19 PM        17,505,704 AWS.xlsx
# 20-Jan-23  04:03 PM            34,988 json_re.csv
# 17-Jan-23  05:20 PM            34,544 json_res.csv
# 20-Jan-23  04:03 PM            78,961 NBA.csv
# 19-Jan-23  03:23 PM            80,712 Pandas_2.ipynb
# 20-Jan-23  03:38 PM           334,444 pandas_Intro_casandra.ipynb
# 16-Jan-23  07:20 PM        84,407,139 ts_transport_vehicle_online_sales_25_10_2018to31_12_2018.csv
# 16-Jan-23  07:32 PM                 0 untitled.txt
#                8 File(s)    102,476,492 bytes
#                3 Dir(s)  60,549,586,944 bytes free

# %%
# Task nested dict extract data
#1.make new column same datasheet 
# fill the data of that from user

# %%
x = df2['user'][0]['login']
x
# Out:
# 'noatamir'

# %%
len(df2)
# Out:
# 30

# %%
y1 =[]
for i in range(len(df2)):
    l_data =(df2['user'][i]['login'])
    y1.append(l_data)

# %%
df2['login'] = y1

# %%
y2 =[]
for i in range(len(df2)):
    l_data =(df2['user'][i]['id'])
    y2.append(l_data)

# %%
df2.head(2)
# Out:
#            id                                                url  \
# 0  1550501173  https://api.github.com/repos/pandas-dev/pandas...
# 1  1550496896  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 user         login
# 0  {'login': 'noatamir', 'id': 6564007, 'node_id'...      noatamir
# 1  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...  MarcoGorelli

# %%
df2['id_user']=y2

# %%
y3 =[]
for i in range(len(df2)):
    l_data =(df2['user'][i]['node_id'])
    y3.append(l_data)

# %%
df2['node_id'] = y3

# %%
df2.columns
# Out:
# Index(['id', 'url', 'repository_url', 'labels_url', 'user', 'login', 'id_user',
#        'node_id'],
#       dtype='object')

# %%
df2['user']
# Out:
# 0     {'login': 'noatamir', 'id': 6564007, 'node_id'...
# 1     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 2     {'login': 'tpackard1', 'id': 46908522, 'node_i...
# 3     {'login': 'datapythonista', 'id': 10058240, 'n...
# 4     {'login': 'mvashishtha', 'id': 10712109, 'node...
# 5     {'login': 'mvashishtha', 'id': 10712109, 'node...
# 6     {'login': 'mvashishtha', 'id': 10712109, 'node...
# 7     {'login': 'mvashishtha', 'id': 10712109, 'node...
# 8     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 9     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 10    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 11    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 12    {'login': 'czroth', 'id': 95671524, 'node_id':...
# 13    {'login': 'topper-123', 'id': 26364415, 'node_...
# 14    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 15    {'login': 'abonte', 'id': 6319051, 'node_id': ...
# 16    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# ...

# %%
df2['user'][0].values()
# Out:
# dict_values(['noatamir', 6564007, 'MDQ6VXNlcjY1NjQwMDc=', 'https://avatars.githubusercontent.com/u/6564007?v=4', '', 'https://api.github.com/users/noatamir', 'https://github.com/noatamir', 'https://api.github.com/users/noatamir/followers', 'https://api.github.com/users/noatamir/following{/other_user}', 'https://api.github.com/users/noatamir/gists{/gist_id}', 'https://api.github.com/users/noatamir/starred{/owner}{/repo}', 'https://api.github.com/users/noatamir/subscriptions', 'https://api.github.com/users/noatamir/orgs', 'https://api.github.com/users/noatamir/repos', 'https://api.github.com/users/noatamir/events{/privacy}', 'https://api.github.com/users/noatamir/received_events', 'User', False])

# %%
x = list(df2['user'][0].values())

# %%
p =[]
for i in range(len(df2['user'])):
    z = list(df2['user'][i].values())
    p.append(z[3])
print(p)
# Out:
# ['https://avatars.githubusercontent.com/u/6564007?v=4', 'https://avatars.githubusercontent.com/u/33491632?v=4', 'https://avatars.githubusercontent.com/u/46908522?v=4', 'https://avatars.githubusercontent.com/u/10058240?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10647082?v=4', 'https://avatars.githubusercontent.com/u/8078968?v=4', 'https://avatars.githubusercontent.com/u/45562402?v=4', 'https://avatars.githubusercontent.com/u/8078968?v=4', 'https://avatars.githubusercontent.com/u/95671524?v=4', 'https://avatars.githubusercontent.com/u/26364415?v=4', 'https://avatars.githubusercontent.com/u/61934744?v=4', 'https://avatars.githubusercontent.com/u/6319051?v=4', 'https://avatars.githubusercontent.com/u/45562402?v=4', 'https://avatars.githubusercontent.com/u/24256554
# ...

# %%
df2['user'][0]['avatar_url']
# Out:
# 'https://avatars.githubusercontent.com/u/6564007?v=4'

# %%
p =[]
for i in range(len(df2['user'])):
    p.append(df2['user'][i]['avatar_url'])
print(p)
# Out:
# ['https://avatars.githubusercontent.com/u/6564007?v=4', 'https://avatars.githubusercontent.com/u/33491632?v=4', 'https://avatars.githubusercontent.com/u/46908522?v=4', 'https://avatars.githubusercontent.com/u/10058240?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10712109?v=4', 'https://avatars.githubusercontent.com/u/10647082?v=4', 'https://avatars.githubusercontent.com/u/8078968?v=4', 'https://avatars.githubusercontent.com/u/45562402?v=4', 'https://avatars.githubusercontent.com/u/8078968?v=4', 'https://avatars.githubusercontent.com/u/95671524?v=4', 'https://avatars.githubusercontent.com/u/26364415?v=4', 'https://avatars.githubusercontent.com/u/61934744?v=4', 'https://avatars.githubusercontent.com/u/6319051?v=4', 'https://avatars.githubusercontent.com/u/45562402?v=4', 'https://avatars.githubusercontent.com/u/24256554
# ...

# %%
p
# Out:
# ['https://avatars.githubusercontent.com/u/6564007?v=4',
#  'https://avatars.githubusercontent.com/u/33491632?v=4',
#  'https://avatars.githubusercontent.com/u/46908522?v=4',
#  'https://avatars.githubusercontent.com/u/10058240?v=4',
#  'https://avatars.githubusercontent.com/u/10712109?v=4',
#  'https://avatars.githubusercontent.com/u/10712109?v=4',
#  'https://avatars.githubusercontent.com/u/10712109?v=4',
#  'https://avatars.githubusercontent.com/u/10712109?v=4',
#  'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'https://avatars.githubusercontent.com/u/45562402?v=4',
#  'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'https://avatars.githubusercontent.com/u/95671524?v=4',
#  'https://avatars.githubusercontent.com/u/26364415?v=4',
#  'https://avatars.githubusercontent.com/u/61934744?v=4',
#  'https://avatars.githubusercontent.com/u/6319051?v=4',
#  'https://avatars.githubusercontent.com/u/45562402?v=4',
# ...

# %%
df2['avtar_url'] = p

# %% [markdown]
# ##

# %%
df2
# Out:
#             id                                                url  \
# 0   1550501173  https://api.github.com/repos/pandas-dev/pandas...
# 1   1550496896  https://api.github.com/repos/pandas-dev/pandas...
# 2   1550298700  https://api.github.com/repos/pandas-dev/pandas...
# 3   1550298038  https://api.github.com/repos/pandas-dev/pandas...
# 4   1550201142  https://api.github.com/repos/pandas-dev/pandas...
# 5   1550197033  https://api.github.com/repos/pandas-dev/pandas...
# 6   1550192983  https://api.github.com/repos/pandas-dev/pandas...
# 7   1550190973  https://api.github.com/repos/pandas-dev/pandas...
# 8   1550120694  https://api.github.com/repos/pandas-dev/pandas...
# 9   1550060102  https://api.github.com/repos/pandas-dev/pandas...
# 10  1550028797  https://api.github.com/repos/pandas-dev/pandas...
# 11  1550004817  https://api.github.com/repos/pandas-dev/pandas...
# 12  1550000207  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
"akshaygp41@gmail.com"
# Out:
# 'akshaygp41@gmail.com'
